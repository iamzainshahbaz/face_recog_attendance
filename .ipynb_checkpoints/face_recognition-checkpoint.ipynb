# %%
from deepface import DeepFace
#liveness
import tensorflow as tf

# %%
import cv2, numpy, datetime, keyboard, pygame, pygame.camera

# %%
model = 'liveness.model'
model = tf.keras.models.load_model(model)

# %%
cap = cv2.VideoCapture(0)

while True:
    
    state, frame = cap.read()
    
    if state!=True:
        break
        
    res  = DeepFace.find(frame, db_path='./Database/', enforce_detection=False, model_name='VGG-Face')
    
    if len(res[0]['identity'])>0:
        
        name = res[0]['identity'][0].split('/')[1].split('\\')[1]
        xmin = int(res[0]['source_x'][0])
        ymin = int(res[0]['source_y'][0])
        
        w = res[0]['source_w'][0]
        h = res[0]['source_h'][0]
        
        xmax = int(xmin + w)
        ymax = int(ymin + h)
        
        #liveness
        
        img = frame[ymin:ymax, xmin:xmax]
        img = cv2.resize(img, (32,32))
        img = img.astype('float')/255.0
        img = tf.keras.preprocessing.image.img_to_array(img)
        img = numpy.expand_dims(img, axis=0)
        
        liveness = model.predict(img)
        
        liveness = liveness[0].argmax()
        
        
        
        cv2.rectangle(frame, (xmin,ymin),(xmax,ymax), (0,255,0),1)
        cv2.rectangle(frame, (xmin, ymin-25),(xmax, ymin),(255,255,255),-1)
        cv2.putText(frame, name, (xmin,ymin), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,0,0),2,cv2.LINE_AA)
        
        if liveness==1:
            cv2.putText(frame, "real", (xmin,ymax+25), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255),2, cv2.LINE_AA)
        else:
            cv2.putText(frame, "fake", (xmin,ymax+25), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255),2, cv2.LINE_AA)
    
    cv2.imshow('attendance', frame)
    
    c = cv2.waitKey(1)
    
    if c == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  1.2929091453552246  seconds
# 1/1 [==============================] - 0s 77ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.1730480194091797  seconds
# 1/1 [==============================] - 0s 13ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16754603385925293  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.17605090141296387  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.1710517406463623  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.17104673385620117  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.17154407501220703  seconds
# 1/1 [==============================] - 0s 11ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.17305254936218262  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.17004847526550293  seconds
# 1/1 [==============================] - 0s 13ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16904830932617188  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.1655418872833252  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16754555702209473  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.1640489101409912  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.1640474796295166  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16504430770874023  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16634368896484375  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16705107688903809  seconds
# 1/1 [==============================] - 0s 13ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16504812240600586  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16304683685302734  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16454172134399414  seconds
# 1/1 [==============================] - 0s 13ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.15921902656555176  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.1635456085205078  seconds
# 1/1 [==============================] - 0s 14ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16304802894592285  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16476130485534668  seconds
# 1/1 [==============================] - 0s 11ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.1660447120666504  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.1635420322418213  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16704821586608887  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.1620481014251709  seconds
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.15716075897216797  seconds
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16125059127807617  seconds
# 1/1 [==============================] - 0s 11ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.1635434627532959  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16704916954040527  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16504359245300293  seconds
# 1/1 [==============================] - 0s 11ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16654181480407715  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16954302787780762  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.1780531406402588  seconds
# 1/1 [==============================] - 0s 15ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.17304658889770508  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.17354655265808105  seconds
# 1/1 [==============================] - 0s 13ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.17004799842834473  seconds
# 1/1 [==============================] - 0s 11ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16704440116882324  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16854262351989746  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.1615428924560547  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.1670544147491455  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.1670520305633545  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16804790496826172  seconds
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16204595565795898  seconds
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16005301475524902  seconds
# 1/1 [==============================] - 0s 14ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.18505191802978516  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16454625129699707  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16605043411254883  seconds
# 1/1 [==============================] - 0s 13ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.1640465259552002  seconds
# 1/1 [==============================] - 0s 13ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.15981030464172363  seconds
# 1/1 [==============================] - 0s 11ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16104602813720703  seconds
# 1/1 [==============================] - 0s 11ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16454148292541504  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16254401206970215  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16104650497436523  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.15862274169921875  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16454100608825684  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16554617881774902  seconds
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.16254115104675293  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.17258810997009277  seconds
# 1/1 [==============================] - 0s 12ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.1710498332977295  seconds
# 1/1 [==============================] - 0s 13ms/step
# WARNING: Representations for images in ./Database/ folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  9  representations found in  representations_vgg_face.pkl
# find function lasts  0.